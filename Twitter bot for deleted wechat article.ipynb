# %% [markdown]
# ## WeChat_Censored
#
# Our bot is a informational bot that tweets out articles that are censored on WeChat, the most popular social media platform in China.
#
# The data source of our bot is from WeChatSCOPE, a project lauched by the University of Hong Kong, which “scrape” data from the WeChat's API. When an article is deleted, the copy of it appears in the database at https://wechatscope.jmsc.hku.hk/api/update_weixin_public_pretty?days=7.
#
# Every time when the database is updated with newly deleted articles, our bot will tweet out the original title, the censored date, the restored link of the article, as well as the reasons why it was deleted. There are three reasons for the deletion of an WeChat article:
# 1. The article was deleted the author;
# 2. The content cannot be viewed due to violations (Received related complaints, the content violates the "Internet User Public Account Information Service Management Regulations")
# 3. The account has been blocked, the content cannot be viewed (Responding to related complaints, the account is suspected of violating the "Regulations on the Management of Public Account Information Services for Internet Users")

# %%
from requests import get

# Specify the location of the information you want as a string

url = 'https://wechatscope.jmsc.hku.hk/api/update_weixin_public?days=7'

# Then fetch the data (the resource) at that address using get() from
# the "requests" package

response = get(url)
data=response.json()
data
# Out:
# [{'url': 'mp.weixin.qq.com/s?__biz=MjM5Njc4NTgzMA==&mid=2650667017&idx=2&sn=f35a7546a9aef9e8c27e95e81c367004',
#   'title': '退伍回家，发现弟弟含冤九泉，一声令下，十万将士直奔而来',
#   'title_eng': 'When the veteran returned home and found that his brother was wronged, Jiuquan was ordered, and one hundred thousand soldiers came straight.',
#   'nickname': '探索者',
#   'created_at': '2020-03-01',
#   'archive': 'gh_715befbd50ba_2020-03-01_2650667017_VYcPnRlA3k.y.tar.gz',
#   'censored_date': '2020-03-03 02:38:13',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-02 12:33:40'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzAwNDE3MjY2Ng==&mid=2653503741&idx=1&sn=2442e802761c678e3b873ebc0f7516ae',
#   'title': '喝酒上头难受，三两就断片？行家教你这样喝酒，酒量翻倍，不难受',
#   'title_eng': 'Drinking is uncomfortable, just break the film? Experts teach you to drink like this',
#   'nickname': '警笛',
#   'created_at': '2020-03-02',
#   'archive': 'gh_2877643e575a_2020-03-02_2653503741_2SAxNuHKzI.y.tar.gz',
#   'censored_date': '2020-03-03 07:46:21',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-02 10:45:21'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5OTkwMzc4Mg==&mid=2652084421&idx=2&sn=9187bbad2050da2e3fbcdef0f1e2a28f',
#   'title': '胡舒立的用人之道',
#   'title_eng': "Hu Shuli's Employment",
#   'nickname': '东方网',
#   'created_at': '2020-03-02',
#   'archive': 'gh_38954511fdfd_2020-03-02_2652084421_pVvaYSg961.y.tar.gz',
#   'censored_date': '2020-03-02 13:36:07',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 09:59:48'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4MzY3NjA0Ng==&mid=2650359004&idx=5&sn=c4910e0068311d0487ff41214ccaff47',
#   'title': '他给爷爷贺寿却不被全家待见，殊不知首富亲自接待，还要下跪叫老大',
#   'title_eng': 'He gave Grandpa his birthday but was not seen by the whole family.',
#   'nickname': '乐诚坊',
#   'created_at': '2020-03-01',
#   'archive': 'gh_42435e819eef_2020-03-01_2650359004_pUeHXuzxTF.y.tar.gz',
#   'censored_date': '2020-03-02 15:02:29',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 11:19:06'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA3Mzg0NjIwOQ==&mid=2649547500&idx=1&sn=19c09b56a620c3d271adbd6622e3197d',
#   'title': '“神医”李跃华是如何趁“疫”打劫的？',
#   'title_eng': 'How did sacred doctor Li Yuehua take advantage of the epidemic?',
#   'nickname': '人生茶馆',
#   'created_at': '2020-03-02',
#   'archive': 'gh_f5afdd146c83_2020-03-02_2649547500_OIK12uk06P.y.tar.gz',
#   'censored_date': '2020-03-03 11:21:26',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-02 15:26:08'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5Njc4NTgzMA==&mid=2650667000&idx=2&sn=37a849717e10c9a45c57d665705a7657',
#   'title': '古董店小哥拿出此物被笑破石头！富商见了：一套房我跟你换了！',
#   'title_eng': 'The antique shop brother took out this object and was broken by a smile! Rich businessmen met: I changed a suite with you!',
#   'nickname': '探索者',
#   'created_at': '2020-02-29',
#   'archive': 'gh_715befbd50ba_2020-02-29_2650667000_ycMl7hwrB5.y.tar.gz',
#   'censored_date': '2020-03-02 12:35:59',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 11:50:54'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI2NDEzMzY1Mg==&mid=2652021229&idx=2&sn=b24b83127b7ac2019740e1bc0d8d1dca',
#   'title': '全球第58位！贵州省2019年营商环境第三方评估报告出炉',
#   'title_eng': "58th in the world! Guizhou Province's 2019 Third-Party Business Environment Assessment Report",
#   'nickname': '多彩贵州网',
#   'created_at': '2020-03-02',
#   'archive': 'gh_6bd4e5daaad0_2020-03-02_2652021229_pgzLbwqZxf.y.tar.gz',
#   'censored_date': '2020-03-02 15:22:17',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 12:08:47'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0NTM4NjM3OQ==&mid=2247492129&idx=1&sn=264421ba23b319c3d2a30d95a72e83dc',
#   'title': '刚刚查出来了！疫情真凶浮出水面，真相颠覆认知！',
#   'title_eng': 'Just found out! The true outbreak of the epidemic surfaced, the truth subverted the perception!',
#   'nickname': '郭一平心念黎民',
#   'created_at': '2020-02-29',
#   'archive': 'gh_a2b44f72c451_2020-02-29_2247492129_1EkW96HzhF.y.tar.gz',
#   'censored_date': '2020-03-02 19:30:26',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-03 17:53:01'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA5MjM2NDcwMg==&mid=2664303731&idx=3&sn=4deca0c995569e1905b35f7ace4ea6d2',
#   'title': '《学术月刊》2020年第2期目录及摘要',
#   'title_eng': 'Catalogue and Abstract of Academic Monthly No. 2 2020',
#   'nickname': '文化纵横',
#   'created_at': '2020-03-01',
#   'archive': 'gh_f85d25e406e2_2020-03-01_2664303731_ZOLiSwhVDj.y.tar.gz',
#   'censored_date': '2020-03-03 17:59:56',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 00:27:26'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MDM4MDExNQ==&mid=2832486025&idx=3&sn=99e72925360ad8655698fdf934ef74d8',
#   'title': '2020，这几个口碑极佳的公众号，你关注了吗？',
#   'title_eng': 'In 2020, these public accounts with excellent reputation have you paid attention?',
#   'nickname': '知乎日报',
#   'created_at': '2020-02-29',
#   'archive': 'gh_e59ba9dfaa66_2020-02-29_2832486025_p1KxTNhimo.y.tar.gz',
#   'censored_date': '2020-03-05 01:58:17',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 18:34:50'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4ODIxNDc2Nw==&mid=2656645430&idx=1&sn=36b5d8855d6137d34073a3997853d338',
#   'title': '围炉特稿：特殊时期媒体何为？ | 围炉 · FDU',
#   'title_eng': 'Special Feature: What is the media in a special period? | Furnace · FDU',
#   'nickname': '围炉',
#   'created_at': '2020-03-02',
#   'archive': 'gh_6768c4e761a2_2020-03-02_2656645430_xlON346Gm0.y.tar.gz',
#   'censored_date': '2020-03-02 22:32:48',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-03 21:04:22'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NjEyMTE5NA==&mid=2650837935&idx=4&sn=fd27149ecf9f5e287abaa072dd3f0915',
#   'title': '人民日报：给民间中医留一条生路',
#   'title_eng': "People's Daily: Leave a Life for Folk TCM",
#   'nickname': '稻田报告',
#   'created_at': '2020-03-02',
#   'archive': 'gh_736c227c132c_2020-03-02_2650837935_psShHvzb7t.y.tar.gz',
#   'censored_date': '2020-03-02 22:46:42',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-03 21:05:53'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIxMjMyMTQyMg==&mid=2247529278&idx=2&sn=2f7010b8beb825661c92891db19207cd',
#   'title': '青岛新视界眼科医院竟将患者赶出手术室，发生了什么？',
#   'title_eng': 'Qingdao New Vision Ophthalmology Hospital actually drove patients out of the operating room. What happened?',
#   'nickname': '凤凰网青岛',
#   'created_at': '2020-03-01',
#   'archive': 'gh_20542841a698_2020-03-01_2247529278_SxJ2nlioQ5.y.tar.gz',
#   'censored_date': '2020-03-03 04:30:24',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-02 16:06:28'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzUzMjEwOTkyOQ==&mid=2247510388&idx=3&sn=6455238b8f4d39ec3a95f09dd11a2065',
#   'title': '判孙杨8年禁赛，实在太重了',
#   'title_eng': 'Sun Yang was suspended for 8 years, which is too heavy',
#   'nickname': '尸人',
#   'created_at': '2020-03-01',
#   'archive': 'gh_cfb5087c307a_2020-03-01_2247510388_bydIwEKBCm.y.tar.gz',
#   'censored_date': '2020-03-03 05:14:08',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-02 17:34:27'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0MTY5NzY0Mg==&mid=2247491243&idx=1&sn=f966f88b2e45850f724e86834c4c826e',
#   'title': '老百姓很纳闷，这到底谁干的？',
#   'title_eng': 'People are wondering, who did this?',
#   'nickname': '遮眼看天',
#   'created_at': '2020-02-28',
#   'archive': 'gh_b984621ff266_2020-02-28_2247491243_o95Md7uQwP.y.tar.gz',
#   'censored_date': '2020-03-03 05:37:47',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-02 18:21:53'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA5Mzc1MzgzNQ==&mid=2650833948&idx=7&sn=742344577dc8987e12262d6825f3a771',
#   'title': '卢菲菲：从中专生到记忆超群，你的潜能会让你成为更好的自己',
#   'title_eng': 'Lu Feifei: From a technical secondary school student to a superb memory, your potential will make you a better self',
#   'nickname': '新闻早餐',
#   'created_at': '2020-03-02',
#   'archive': 'gh_11d6ef0dd9d4_2020-03-02_2650833948_B0hnGSTofj.y.tar.gz',
#   'censored_date': '2020-03-03 06:42:54',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-02 08:29:42'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI0OTcwMTc4Ng==&mid=2247501350&idx=1&sn=f75d851ab94cf63e781e014b0acc7b59',
#   'title': '饭局上这种白酒不敢喝了，后悔知道晚了？酒厂酿酒师揭秘白酒丑陋内幕',
#   'title_eng': 'I do n’t dare to drink this kind of liquor at dinner. I regret knowing it ’s late? Winery winemaker reveals ugly inside of liquor',
#   'nickname': '今日防务观察',
#   'created_at': '2020-03-02',
#   'archive': 'gh_c225404568b3_2020-03-02_2247501350_TZ9SW2GOxH.y.tar.gz',
#   'censored_date': '2020-03-02 12:26:07',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-03 11:28:24'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5OTY0NjA4MQ==&mid=2650096398&idx=7&sn=0c6862e90e7a24473b3c1bf430f99080',
#   'title': '【关注】产品宣传问题引人关注，揭底四级代理的“禅吻”是何来历？',
#   'title_eng': '[Focus] The issue of product promotion attracts attention. How did the zen kiss of the fourth-level agent come to be?',
#   'nickname': '反传联盟',
#   'created_at': '2020-03-03',
#   'archive': 'gh_65c37a6436e8_2020-03-03_2650096398_ULJui9XNKq.y.tar.gz',
#   'censored_date': '2020-03-03 13:03:33',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 11:32:43'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5Njc4NTgzMA==&mid=2650667029&idx=2&sn=c7acdeada6010135f5f1a2de37931fbf',
#   'title': '父母失踪，亲弟自杀，五年后荣耀归来，立誓要让小人百倍償還！',
#   'title_eng': 'His parents disappeared, his brother committed suicide. Five years later, he returned with glory. He vowed to repay the villain a hundred times!',
#   'nickname': '探索者',
#   'created_at': '2020-03-02',
#   'archive': 'gh_715befbd50ba_2020-03-02_2650667029_0xtKD0rpOz.y.tar.gz',
#   'censored_date': '2020-03-04 11:41:38',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 16:49:56'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5OTYwOTM0Nw==&mid=2650100343&idx=1&sn=9ba93acd40ac0e3baac86d7ce9722838',
#   'title': '从“中国之光”到倒闭破产，北大方正做错了什么？',
#   'title_eng': 'From Light of China to bankruptcy and bankruptcy, what did Peking University do wrong?',
#   'nickname': '酷玩实验室',
#   'created_at': '2020-02-29',
#   'archive': 'gh_f33ea5eaf126_2020-02-29_2650100343_cPrt5j2eiR.y.tar.gz',
#   'censored_date': '2020-03-02 17:47:58',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-03 15:18:42'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4MzY3NjA0Ng==&mid=2650359075&idx=5&sn=b35d83e70c3a756d6bae1adf25014bff',
#   'title': '2020年如何快速走出财务困境，危机之下的转机原来在这里！',
#   'title_eng': 'How to quickly get out of financial difficulties in 2020, the turnaround under the crisis is here!',
#   'nickname': '乐诚坊',
#   'created_at': '2020-03-03',
#   'archive': 'gh_42435e819eef_2020-03-03_2650359075_BeqVkfs1uM.y.tar.gz',
#   'censored_date': '2020-03-06 01:52:12',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 14:11:26'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI0OTcwMTc4Ng==&mid=2247501359&idx=1&sn=782c6858c40c1e456849e5c048a7d4ce',
#   'title': '疫情消退，湖北迎来第二场硬仗',
#   'title_eng': 'Epidemic subsides, Hubei usher in second hard battle',
#   'nickname': '今日防务观察',
#   'created_at': '2020-03-03',
#   'archive': 'gh_c225404568b3_2020-03-03_2247501359_Vx4DnGrH2f.y.tar.gz',
#   'censored_date': '2020-03-04 15:16:22',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-06 02:20:37'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5ODAzMjQxMg==&mid=2650365268&idx=1&sn=45fe9d9aef8f1fe627eada7c0f168796',
#   'title': '女人“糟蹋”脸蛋的三个特殊行为，敷面膜竟然排第一，还有......',
#   'title_eng': "Three special behaviors of a woman's bad face, the mask is ranked first, and ...",
#   'nickname': '江南都市报',
#   'created_at': '2020-03-03',
#   'archive': 'gh_b62058001651_2020-03-03_2650365268_paBZuiWv6M.y.tar.gz',
#   'censored_date': '2020-03-03 18:08:29',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-05 03:55:23'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzAxMjk0ODM0Ng==&mid=2247485897&idx=1&sn=a62a5d707a3e44f453096a1a670f2478',
#   'title': '程凌虚抄袭证据实录',
#   'title_eng': "Cheng Ling's plagiarism evidence",
#   'nickname': '苍山夜谈',
#   'created_at': '2020-03-03',
#   'archive': 'gh_d487d6714a24_2020-03-03_2247485897_YHj0mNS86l.y.tar.gz',
#   'censored_date': '2020-03-03 22:02:54',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-04 16:39:19'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI0NTc0MDE4OA==&mid=2247491462&idx=1&sn=5b1f3c3e84cd604502d9bfb08ef538ab',
#   'title': '屠呦呦再次落选院士：没有博士学位，论文数量不够',
#   'title_eng': 'Tu Yi loses academician again: no doctoral degree, not enough thesis',
#   'nickname': '天狐观察',
#   'created_at': '2020-03-03',
#   'archive': 'gh_fd5f7267524b_2020-03-03_2247491462_QYwg2E1AWd.y.tar.gz',
#   'censored_date': '2020-03-04 17:25:01',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 00:02:50'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MTI4MjUxMw==&mid=2653666516&idx=1&sn=187d6636bd2759a93095d20a9dc10fab',
#   'title': '独家 | 阿里拟退出，博雅天下何去何从？',
#   'title_eng': 'Exclusive | Ali intends to withdraw, where does Boya World go from here?',
#   'nickname': 'AI蓝媒汇',
#   'created_at': '2020-03-02',
#   'archive': 'gh_58828820c375_2020-03-02_2653666516_vDKSi3qdrR.y.tar.gz',
#   'censored_date': '2020-03-03 19:44:56',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 19:06:57'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA3ODgzODAzNA==&mid=2660455954&idx=1&sn=a6ff4bd8c067da68edd32ab19a4fccb0',
#   'title': '\u200b华生：疫情的第一道防线',
#   'title_eng': 'Watson: The first line of defense for the epidemic',
#   'nickname': '徐瑾经济人',
#   'created_at': '2020-03-03',
#   'archive': 'gh_1137e6936d9f_2020-03-03_2660455954_5zuMnSCfk2.y.tar.gz',
#   'censored_date': '2020-03-03 20:31:59',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 19:07:43'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5ODQ5ODE5Ng==&mid=2651243110&idx=1&sn=ecb8193ccd42a343626927bf74b85b1e',
#   'title': '新冠肺炎疫情中，中文媒体如何进行可视化报道？',
#   'title_eng': 'How does the Chinese media visualize the new crown pneumonia epidemic?',
#   'nickname': '全球深度报道网',
#   'created_at': '2020-03-03',
#   'archive': 'gh_8abc654c861a_2020-03-03_2651243110_bw0vUn1zCJ.y.tar.gz',
#   'censored_date': '2020-03-03 20:47:52',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 20:21:35'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4NzcwMDQxMg==&mid=2653550528&idx=1&sn=dafb8953201453db6b32e1e4a4d8725e',
#   'title': '非洲黑人，请不要祸害中国妇女',
#   'title_eng': 'Black Africans, please do n’t harm Chinese women',
#   'nickname': '简笔笑画',
#   'created_at': '2020-03-03',
#   'archive': 'gh_c364747d22d0_2020-03-03_2653550528_SV6UWLl7Eb.y.tar.gz',
#   'censored_date': '2020-03-04 20:33:51',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 00:41:58'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4MTkzMTYwMw==&mid=2751376645&idx=5&sn=a722be78c230f099f683f0ac53b273fe',
#   'title': '德国变态发明，这款变态洗发皂，7天发量暴增！男同事亲测，20天浓密乌黑！',
#   'title_eng': 'German abnormal invention, this abnormal shampoo, hair volume surged in 7 days! Male colleague personally tested, 20 days thick black!',
#   'nickname': '葫芦岛都市网',
#   'created_at': '2020-03-01',
#   'archive': 'gh_8dd3af29215d_2020-03-01_2751376645_DRwgHVuyKn.y.tar.gz',
#   'censored_date': '2020-03-03 23:41:03',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-02 16:22:47'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NjAyMTYyMg==&mid=2658292157&idx=3&sn=d6f4dbd873c5f7fe064047d9321e8b80',
#   'title': '华为杀入车机，鸿蒙大军将至？',
#   'title_eng': 'Huawei enters the car, Hongmeng army is coming?',
#   'nickname': '创业财经汇',
#   'created_at': '2020-03-01',
#   'archive': 'gh_f8d73b28357d_2020-03-01_2658292157_Vg0CSW6Frk.y.tar.gz',
#   'censored_date': '2020-03-04 00:05:04',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-02 17:24:43'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIzMTY2NTc0OQ==&mid=2247485752&idx=2&sn=f6a15a01345730b92e1b9f0b0f91124a',
#   'title': '都说日本危险了！国人回过神来：是我们搞错了！',
#   'title_eng': 'Everyone says Japan is dangerous! The Chinese came back to God: we were wrong!',
#   'nickname': '秘闻爆光',
#   'created_at': '2020-03-01',
#   'archive': 'gh_94d9b14108ec_2020-03-01_2247485752_CNv6zIFRhc.y.tar.gz',
#   'censored_date': '2020-03-04 00:12:00',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-02 17:40:38'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI0NTc0MDE4OA==&mid=2247491462&idx=3&sn=80c53b31bde245f9486b107d9b8d606e',
#   'title': '逐条分析《外国人永居管理条例》的问题',
#   'title_eng': 'Analyze the issues of the Regulations on the Management of Permanent Residence of Foreigners',
#   'nickname': '天狐观察',
#   'created_at': '2020-03-03',
#   'archive': 'gh_fd5f7267524b_2020-03-03_2247491462_0qg5hJvtAK.y.tar.gz',
#   'censored_date': '2020-03-04 00:02:26',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-05 09:42:25'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI5OTUwNDQ1NQ==&mid=2247487174&idx=1&sn=848b5b7bf3cb8881bc3561d95d5fd0d0',
#   'title': '请看 | 此刻，我们应该看向什么？',
#   'title_eng': 'See | What should we look at now?',
#   'nickname': 'LoveRediscover',
#   'created_at': '2020-03-04',
#   'archive': 'gh_925701c96584_2020-03-04_2247487174_6GRlQj8YAu.y.tar.gz',
#   'censored_date': '2020-03-05 09:43:57',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-04 08:28:49'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI3NTMyMzQ2MA==&mid=2247517186&idx=1&sn=dbf26c9482827b893689ec628e1787b7',
#   'title': '他，让美联储降息救来个&quot;猴市&quot;?',
#   'title_eng': 'He, let the Federal Reserve cut interest rates to save one',
#   'nickname': '米宅海外',
#   'created_at': '2020-03-04',
#   'archive': 'gh_c0f86219e242_2020-03-04_2247517186_p0jIefi0Du.y.tar.gz',
#   'censored_date': '2020-03-05 11:02:37',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-04 10:43:24'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI4NTMzMjExMw==&mid=2247493049&idx=1&sn=e593cc0761f8e29a42c5940293436342',
#   'title': '武汉疫情下，像方方这么硬核的，武大里至少还有3个',
#   'title_eng': 'In the Wuhan epidemic, there are at least three in Dali like Fang Fang',
#   'nickname': '苍山夜语',
#   'created_at': '2020-03-03',
#   'archive': 'gh_430799a6ef46_2020-03-03_2247493049_pPLuC78Rs3.y.tar.gz',
#   'censored_date': '2020-03-04 09:27:13',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 11:08:11'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA5NzQwMTQ3OQ==&mid=2649482765&idx=2&sn=0438ea8c1a580cb68c98ba0de6e0d6d1',
#   'title': '囤粮囤枪的美国，我不想待下去了！现在回国还来得及吗？',
#   'title_eng': 'I do n’t want to stay in the US Is it too late to return home now?',
#   'nickname': '洛杉矶华人圈',
#   'created_at': '2020-03-03',
#   'archive': 'gh_179ef88e69be_2020-03-03_2649482765_ZMuh50TeO1.y.tar.gz',
#   'censored_date': '2020-03-04 09:57:59',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-03 12:34:25'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA5MDk2NzczMQ==&mid=2651245219&idx=2&sn=2deb57f9be812619b90b5e2273e5cf7c',
#   'title': '如何理性探讨外国人永居条例',
#   'title_eng': 'How to Rationally Explore the Permanent Residence Regulations of Foreigners',
#   'nickname': '法意读书',
#   'created_at': '2020-03-03',
#   'archive': 'gh_491e65fdbff7_2020-03-03_2651245219_iHmBp14cUJ.y.tar.gz',
#   'censored_date': '2020-03-04 10:00:19',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-03 12:28:36'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5ODA3NjQ4MA==&mid=2655494334&idx=1&sn=a757b702ae8ee601033055da9e66472a',
#   'title': '如何面对患难，基督徒要知道这三点！',
#   'title_eng': 'How to face adversity, Christians need to know these three things!',
#   'nickname': '福音时报',
#   'created_at': '2020-03-04',
#   'archive': 'gh_9941bc964b91_2020-03-04_2655494334_uNcWbUC2o9.y.tar.gz',
#   'censored_date': '2020-03-05 14:21:32',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-04 14:42:30'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI5MDI4MjY4MA==&mid=2247489375&idx=5&sn=f0d849938b5c483fcd008e578b9a9a0e',
#   'title': '方方：自己做的选择，就要勇于承担选择的结果',
#   'title_eng': 'Fang Fang: When you make your own choice, you must be brave enough to bear the result of your choice',
#   'nickname': '洞见环球',
#   'created_at': '2020-03-02',
#   'archive': 'gh_303ec1b5ec96_2020-03-02_2247489375_tbWeCHq7Vi.y.tar.gz',
#   'censored_date': '2020-03-03 14:56:45',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-04 12:43:41'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU1ODUxNTA4NA==&mid=2247489690&idx=1&sn=c9779e5396776c55289d73257d5a794e',
#   'title': '注意！涨价潮可能比你想象的还要广泛！',
#   'title_eng': 'note! The rise in prices may be even wider than you think!',
#   'nickname': '时代观察团',
#   'created_at': '2020-03-04',
#   'archive': 'gh_b1dc53661818_2020-03-04_2247489690_T0Npe1tXGL.y.tar.gz',
#   'censored_date': '2020-03-05 15:13:04',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-04 15:31:27'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MTA3NDM1MzUwMQ==&mid=2651992848&idx=2&sn=e5c367d0e8cfac8bcb911ba76224f73b',
#   'title': '杰克•韦尔奇的危机领导力\u200b',
#   'title_eng': "Jack Welch's crisis leadership",
#   'nickname': 'i黑马',
#   'created_at': '2020-03-04',
#   'archive': 'wxid_2965349653612_2020-03-04_2651992848_9t03iyAanW.y.tar.gz',
#   'censored_date': '2020-03-04 12:24:49',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 15:09:56'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5OTkwMzc4Mg==&mid=2652084609&idx=2&sn=7d5b59314a3db51442d3fbcb5904f9d4',
#   'title': '3日全国新增确诊119例，其中湖北115例（武汉114例），上海0新增',
#   'title_eng': 'On the 3rd, 119 new cases were confirmed nationwide, including 115 cases in Hubei (114 cases in Wuhan) and 0 in Shanghai.',
#   'nickname': '东方网',
#   'created_at': '2020-03-04',
#   'archive': 'gh_38954511fdfd_2020-03-04_2652084609_O9UqWG0Br5.y.tar.gz',
#   'censored_date': '2020-03-04 12:29:57',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 15:10:18'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjEwNjI0NzM4MQ==&mid=2670274248&idx=1&sn=01503d38f91c384c0118799636c4f6b6',
#   'title': '重磅！广州公寓、商铺不再限定销售对象',
#   'title_eng': 'Heavy! Guangzhou apartments and shops no longer limit sales targets',
#   'nickname': '南方日报',
#   'created_at': '2020-03-03',
#   'archive': 'wxid_2439084392221_2020-03-03_2670274248_t2N4Fwu58v.y.tar.gz',
#   'censored_date': '2020-03-04 12:43:18',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 15:23:12'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NTk5ODI4NQ==&mid=2655330003&idx=1&sn=c75f1d2be121ac906407a7f2d7d17202',
#   'title': '泪目！女孩追忆逝去男友：武汉，我恨你！',
#   'title_eng': 'Tears! Girl remembers her dead boyfriend: Wuhan, I hate you!',
#   'nickname': '您懂的',
#   'created_at': '2020-03-02',
#   'archive': 'gh_8f7ba5d0b6e2_2020-03-02_2655330003_37fMIiuXmZ.y.tar.gz',
#   'censored_date': '2020-03-04 13:21:55',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 15:24:22'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA5MjM2NDcwMg==&mid=2664303731&idx=2&sn=35bec12167be5516998b8df76d4bb2bb',
#   'title': '探索与争鸣·新刊速递｜2020.02',
#   'title_eng': 'Exploration and Contention · News Express ｜ 2020.02',
#   'nickname': '文化纵横',
#   'created_at': '2020-03-01',
#   'archive': 'gh_f85d25e406e2_2020-03-01_2664303731_PwR0Sh7vti.y.tar.gz',
#   'censored_date': '2020-03-03 18:00:18',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 16:15:06'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzMzOTU4Mg==&mid=2651203782&idx=2&sn=e425bcb4190ad186b3a9868ce35bfc15',
#   'title': '[Mar 2, 6pm] COVID-19 Update: Rumors Busted, Latest Numbers',
#   'title_eng': '[Mar 2, 6pm] COVID-19 Update: Rumors Busted, Latest Numbers',
#   'nickname': 'theBeijinger',
#   'created_at': '2020-03-02',
#   'archive': 'gh_5189ed7a15c7_2020-03-02_2651203782_ezLZTPVbSF.y.tar.gz',
#   'censored_date': '2020-03-02 23:21:27',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 19:34:51'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIxOTE3NTUxNQ==&mid=2651382603&idx=4&sn=d570c74f94af18ae50baec071b05d921',
#   'title': '怀远街道办：我们的“抗疫”二三事',
#   'title_eng': 'Huaiyuan Sub-district Office: Two or three things about our anti-epidemic',
#   'nickname': '横山宣传',
#   'created_at': '2020-03-03',
#   'archive': 'gh_2f772f88268b_2020-03-03_2651382603_TzdNbUDLqQ.y.tar.gz',
#   'censored_date': '2020-03-04 19:23:38',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 20:59:36'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5ODAzNTc2NA==&mid=2652883901&idx=1&sn=5515df939c717317a2e31783e2f86599',
#   'title': '神医降世 ? 更像是一个妄人',
#   'title_eng': 'The magician came to the world? More like a foolish man',
#   'nickname': '呦呦鹿鸣',
#   'created_at': '2020-03-03',
#   'archive': 'gh_228524cee8a6_2020-03-03_2652883901_o37dFgz4Dy.y.tar.gz',
#   'censored_date': '2020-03-04 19:49:28',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 21:50:09'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MTI4MjUxMw==&mid=2653666527&idx=2&sn=3a9e51270afc789c5cfbde8a01f6367c',
#   'title': '招聘｜南方周末、中国旅游报、中国改革报/改革网湾区智库、人民日报、光明日报',
#   'title_eng': "Recruitment ｜ Southern Weekend, China Tourism News, China Reform News / China Reform Net Bay Area Think Tank, People's Daily, Guangming Daily",
#   'nickname': 'AI蓝媒汇',
#   'created_at': '2020-03-03',
#   'archive': 'gh_58828820c375_2020-03-03_2653666527_euPQ8Cw9Xn.y.tar.gz',
#   'censored_date': '2020-03-05 22:57:19',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 00:29:21'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MTIzNTA0MA==&mid=2651747835&idx=4&sn=ba0b18465e3fa06e4fc9377d62e76b63',
#   'title': '疫情下，海外华人遭受的歧视远比我们想像得要严重...',
#   'title_eng': 'Under the epidemic, overseas Chinese have suffered more discrimination than we thought ...',
#   'nickname': '带你游遍英国',
#   'created_at': '2020-03-03',
#   'archive': 'gh_336ea9863c03_2020-03-03_2651747835_r7anjzq3dv.y.tar.gz',
#   'censored_date': '2020-03-06 00:32:18',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 01:23:01'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIzMTY2NTc0OQ==&mid=2247485754&idx=1&sn=57ae0f137468c5dea03e70c1d78c084b',
#   'title': '口罩掩盖下的贫穷：5.6亿人存款为0…',
#   'title_eng': 'Masked Poverty: 560 Million People Deposit 0 ...',
#   'nickname': '秘闻爆光',
#   'created_at': '2020-03-02',
#   'archive': 'gh_94d9b14108ec_2020-03-02_2247485754_sFoA0ySmXE.y.tar.gz',
#   'censored_date': '2020-03-03 16:43:21',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-05 01:07:17'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA5Mjk2NjEyNw==&mid=2651612268&idx=1&sn=a4060d11babb9f1ce1a4fa964a58fc11',
#   'title': '中国男孩太惨了',
#   'title_eng': 'Chinese boy is too miserable',
#   'nickname': '格林威治嬉皮研究公社',
#   'created_at': '2020-03-02',
#   'archive': 'gh_929de71f2df8_2020-03-02_2651612268_GU190RFXbQ.y.tar.gz',
#   'censored_date': '2020-03-03 00:55:20',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 02:04:30'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIxMjcxNzkwNA==&mid=2247487213&idx=1&sn=4c228a88b504815ee49baf202dfb66f9',
#   'title': '它是“天然青霉素”，每天一杯，肠胃通了，肚子小了，提高免疫力，医生称它为血管清道夫！',
#   'title_eng': 'It is natural penicillin, one cup a day, the stomach and stomach are open, the stomach is small, and the immunity is improved.',
#   'nickname': '海外独立频道',
#   'created_at': '2020-03-04',
#   'archive': 'gh_fe6bb4bdd14d_2020-03-04_2247487213_sYQehCKt6A.y.tar.gz',
#   'censored_date': '2020-03-05 10:52:04',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 12:59:00'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MjMxODAzMQ==&mid=2652689079&idx=1&sn=89dfde7daa95cebfc98de08c4b368969',
#   'title': '为何降低外国人永居门槛也不放开生育？',
#   'title_eng': 'Why not lower the threshold for foreigners to live permanently?',
#   'nickname': '泽平宏观',
#   'created_at': '2020-03-04',
#   'archive': 'gh_55444ada89cc_2020-03-04_2652689079_d8uxlTHifP.y.tar.gz',
#   'censored_date': '2020-03-05 13:51:47',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-04 13:13:00'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953616&idx=3&sn=1ea8b5ef0295f111e17c75a290935f48',
#   'title': '深度文章：福音是怎样传开的？(含音频)',
#   'title_eng': 'In-depth article: How did the gospel spread? (With audio)',
#   'nickname': '生命季刊',
#   'created_at': '2020-03-05',
#   'archive': 'gh_785a6e62ca80_2020-03-05_2688953616_afU2OgGekr.y.tar.gz',
#   'censored_date': '2020-03-07 02:30:56',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 11:33:42'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953600&idx=1&sn=cd94234e4c0ad736f6782e1295d107c8',
#   'title': '今日灵修:爱心多而又多(含音频)',
#   'title_eng': 'Devotion Today: Many Loves (With Audio)',
#   'nickname': '生命季刊',
#   'created_at': '2020-03-04',
#   'archive': 'gh_785a6e62ca80_2020-03-04_2688953600_BohMdapsDi.y.tar.gz',
#   'censored_date': '2020-03-07 02:31:19',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 11:34:05'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953600&idx=2&sn=b7a77c88923c3b2b366f069f5d91f426',
#   'title': '访谈:美国神学家派博谈病毒(含音频)',
#   'title_eng': 'Interview: American theologian Piper on the virus (with audio)',
#   'nickname': '生命季刊',
#   'created_at': '2020-03-04',
#   'archive': 'gh_785a6e62ca80_2020-03-04_2688953600_iZ2RXuDsmy.y.tar.gz',
#   'censored_date': '2020-03-07 02:31:42',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 11:34:28'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953600&idx=3&sn=e1c2131880352b900c20a89b633ca969',
#   'title': '美国加州华人:大米被抢购光了,你怎么办?(含音频)',
#   'title_eng': 'Chinese in California: Rice is sold out, what do you do? (With audio)',
#   'nickname': '生命季刊',
#   'created_at': '2020-03-04',
#   'archive': 'gh_785a6e62ca80_2020-03-04_2688953600_o4g6WmFMye.y.tar.gz',
#   'censored_date': '2020-03-07 02:32:05',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 11:34:51'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953616&idx=2&sn=86cf18a8083f48a62dc28f875f4e4471',
#   'title': '王明道：为什么祂不能住在伯利恒？',
#   'title_eng': "Wang Mingdao: Why can't He live in Bethlehem?",
#   'nickname': '生命季刊',
#   'created_at': '2020-03-05',
#   'archive': 'gh_785a6e62ca80_2020-03-05_2688953616_w4HdezEIYp.y.tar.gz',
#   'censored_date': '2020-03-07 02:30:34',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 11:33:18'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4MTI2MTg2Mg==&mid=2247492812&idx=3&sn=f6fe8994e16e31dcd70bd9802ef20da5',
#   'title': '钟南山母亲的不幸离去：难以言说的痛......',
#   'title_eng': "The unfortunate departure of Zhong Nanshan's mother: Unspeakable pain ...",
#   'nickname': '前沿观察网',
#   'created_at': '2020-03-05',
#   'archive': 'gh_da91e6008b7f_2020-03-05_2247492812_AExHqD6TSh.y.tar.gz',
#   'censored_date': '2020-03-06 12:12:28',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-08 01:26:38'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4MzY3NjA0Ng==&mid=2650359142&idx=4&sn=9b4715c9230d61842c98a8cea41f4a21',
#   'title': '上级秘密任务，他成为明家的赘婿，从此龙潜都市，猛虎出岬',
#   'title_eng': 'A secret mission at a higher level, he became a burden to the Ming family.',
#   'nickname': '乐诚坊',
#   'created_at': '2020-03-05',
#   'archive': 'gh_42435e819eef_2020-03-05_2650359142_cQb7zlYCsw.y.tar.gz',
#   'censored_date': '2020-03-07 04:53:44',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 16:39:53'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA3MjQ3NTcxNw==&mid=2651264542&idx=5&sn=b968a1270709f96e0e8dfad42d6d4e2c',
#   'title': '澳股日评|七连阴终结澳指周二反弹   降息幅度低于预期大盘涨幅收窄',
#   'title_eng': 'Australian Stocks Daily Commentary | Seven Lianyin ends Australian index rebounded on Tuesday, interest rate cuts were lower than expected, market gains narrowed',
#   'nickname': '澳华财经在线',
#   'created_at': '2020-03-04',
#   'archive': 'gh_8b33b85a7684_2020-03-04_2651264542_hY4UVr02W1.y.tar.gz',
#   'censored_date': '2020-03-04 15:38:26',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 18:55:09'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU1ODQzODQ1Mw==&mid=2247485171&idx=1&sn=31104bcb280c8e018607f852109f1f22',
#   'title': '喝了这么多年酱香酒，才知道原来酱香酒有这么多来历…',
#   'title_eng': 'After drinking soy sauce wine for so many years, I know that soy sauce wine has so many origins ...',
#   'nickname': '世界华人杂谈',
#   'created_at': '2020-03-04',
#   'archive': 'gh_4398a0eeb2f3_2020-03-04_2247485171_EywD6c82N5.y.tar.gz',
#   'censored_date': '2020-03-05 20:42:23',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 19:32:16'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NTE0ODc2Nw==&mid=2650464947&idx=2&sn=10f826c8a150253132fcda5f8148298e',
#   'title': '安倍：3月9日至月底，暂停中韩两国驻日使馆已发签证的效力',
#   'title_eng': 'Abe: From March 9th to the end of the month, the effectiveness of the visas issued by the Chinese and Korean embassies in Japan will be suspended',
#   'nickname': '界面新闻',
#   'created_at': '2020-03-05',
#   'archive': 'gh_93119cc8064a_2020-03-05_2650464947_HnIoya0i8R.y.tar.gz',
#   'censored_date': '2020-03-06 19:32:38',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 07:08:08'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MTc4MTM2Ng==&mid=2650109090&idx=6&sn=3d1faf03fb70e121bac85ae287481566',
#   'title': '“我想逃出武汉！”',
#   'title_eng': 'I want to escape Wuhan!',
#   'nickname': '朝報',
#   'created_at': '2020-03-05',
#   'archive': 'gh_5a083ac7d06d_2020-03-05_2650109090_ywXBD3tT0P.y.tar.gz',
#   'censored_date': '2020-03-06 21:47:59',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-07 09:22:36'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIzMTY2NTc0OQ==&mid=2247485758&idx=2&sn=75469d5e554eb8890ea4315334961fd5',
#   'title': '张文宏：不尽快复工，死亡率将高于新冠病毒！',
#   'title_eng': 'Zhang Wenhong: If you do not resume work as soon as possible, the mortality rate will be higher than the new crown virus!',
#   'nickname': '秘闻爆光',
#   'created_at': '2020-03-03',
#   'archive': 'gh_94d9b14108ec_2020-03-03_2247485758_XM0wSIyP0J.y.tar.gz',
#   'censored_date': '2020-03-04 21:09:59',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-05 22:47:37'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0NTYxNTk0Mg==&mid=2247492203&idx=1&sn=818499117a8c22401bcd8a3fe67bbbfd',
#   'title': '来，跟我在长安街上调个头',
#   'title_eng': "Come, turn around with me on Chang'an Street",
#   'nickname': '高碎说一不二',
#   'created_at': '2020-03-04',
#   'archive': 'gh_ae5bc138b1e1_2020-03-04_2247492203_UywFOfShEM.y.tar.gz',
#   'censored_date': '2020-03-04 22:45:52',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-06 00:22:40'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4Mzg0NDIzNg==&mid=2655069258&idx=5&sn=9ccfbcec50dcc6679834cc6ef76d55d4',
#   'title': '建设清廉张家界（一）监督守则',
#   'title_eng': 'Building a Clean and Honest Zhangjiajie (I) Supervision Code',
#   'nickname': '掌上张家界',
#   'created_at': '2020-03-05',
#   'archive': 'gh_7ce7fa0b919e_2020-03-05_2655069258_iIfuDX0rJe.y.tar.gz',
#   'censored_date': '2020-03-06 00:55:25',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 23:21:40'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIwMTkxMDUxNA==&mid=2247497248&idx=1&sn=69f85d53fe5faca484a4beb25653cbf5',
#   'title': '6部高分美剧，边看边提高听力，坚持每天学习，学费全返免费学！',
#   'title_eng': '6 high-scoring American dramas, improve listening while watching, insist on studying every day, and return tuition for free!',
#   'nickname': '洛阳人事',
#   'created_at': '2020-03-03',
#   'archive': 'gh_afad949b93dd_2020-03-03_2247497248_fWGe0x8SEK.y.tar.gz',
#   'censored_date': '2020-03-06 01:38:42',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 13:57:50'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4MzY3NjA0Ng==&mid=2650359075&idx=4&sn=5cc6f86ee27734c47c0ede4dcf76400b',
#   'title': '传奇佣兵低调应聘保镖，秘密保护自己未婚妻：别碰她！我能打一百个！',
#   'title_eng': "The legendary mercenary applies a low-key bodyguard to protect his fiancee secretly: Don't touch her! I can hit a hundred!",
#   'nickname': '乐诚坊',
#   'created_at': '2020-03-03',
#   'archive': 'gh_42435e819eef_2020-03-03_2650359075_DtWPx0lsph.y.tar.gz',
#   'censored_date': '2020-03-06 01:51:49',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-04 14:18:22'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA5ODE2NDI5NA==&mid=2653215843&idx=1&sn=58171021ac75a1230536d31a794097a6',
#   'title': '蚕丝被被央视曝光了！原来它.....没看的赶紧看看吧',
#   'title_eng': 'Silk was exposed by CCTV! It turned out ..... hurry up and take a look',
#   'nickname': '腾飞讲史',
#   'created_at': '2020-03-06',
#   'archive': 'gh_8492bb8e8be7_2020-03-06_2653215843_hfVuRJqAO5.y.tar.gz',
#   'censored_date': '2020-03-07 11:18:45',
#   'censored_msg': '该内容已被发布者删除'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA3MTY3MjUxOQ==&mid=2655117279&idx=3&sn=e553540a0e77f64602eb41784a65d745',
#   'title': '那些湖北作家：方方、池莉、胡發雲和蔣方舟 | 觀察',
#   'title_eng': 'Those Hubei writers: Fang Fang, Chi Li, Hu Fayun, and Jiang Fangzhou | Observe',
#   'nickname': '獨家',
#   'created_at': '2020-03-05',
#   'archive': 'gh_ca61f31ea9cc_2020-03-05_2655117279_0ioUaLFgHb.y.tar.gz',
#   'censored_date': '2020-03-05 10:31:37',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 09:56:52'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MTk1MjIwODAwMQ==&mid=2650845982&idx=1&sn=6c24cfca76c2815ecc606d562ff1c826',
#   'title': '明天不上网课了，行吗......',
#   'title_eng': 'No class online tomorrow, all right ...',
#   'nickname': '南方都市报',
#   'created_at': '2020-03-05',
#   'archive': 'wxid_4783107810411_2020-03-05_2650845982_FjbX9AxhJ1.y.tar.gz',
#   'censored_date': '2020-03-06 10:38:43',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 12:57:11'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI4MTk2NTg3Mg==&mid=2247505676&idx=1&sn=41052af0ff7861d76254d1778101aa2b',
#   'title': '武汉封城第43天，我问了方方一些日记之外的“批评”问题',
#   'title_eng': 'On the 43rd day of Wuhan ’s closure, I asked Fang Fang some “criticism” questions outside his diary',
#   'nickname': '骚客文艺',
#   'created_at': '2020-03-05',
#   'archive': 'gh_64365b45f489_2020-03-05_2247505676_dCGXiDxKTo.y.tar.gz',
#   'censored_date': '2020-03-06 11:15:33',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-05 14:37:33'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953637&idx=3&sn=3b905dd5d075b5baebaab0af8e4d3489',
#   'title': '顺从圣灵：要脱离罪，是要受点苦的!(含音频)',
#   'title_eng': 'Obedience to the Holy Spirit: To be free from sin is to suffer! (With audio)',
#   'nickname': '生命季刊',
#   'created_at': '2020-03-06',
#   'archive': 'gh_785a6e62ca80_2020-03-06_2688953637_R45fBaIHSP.y.tar.gz',
#   'censored_date': '2020-03-07 13:58:42',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 16:31:14'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0NTM4NjM3OQ==&mid=2247492153&idx=1&sn=29343ccc087a2fc1f2948bc917424df8',
#   'title': '它是“天然青霉素”，每天一杯，提高免疫力，医生称它为血管清道夫！',
#   'title_eng': 'It is natural penicillin, one cup a day to boost immunity, and doctors call it a blood vessel scavenger!',
#   'nickname': '郭一平心念黎民',
#   'created_at': '2020-03-05',
#   'archive': 'gh_a2b44f72c451_2020-03-05_2247492153_Nv3yzkWKSe.y.tar.gz',
#   'censored_date': '2020-03-05 18:05:07',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-06 16:51:26'},
#  {'url': 'mp.weixin.qq.com/s?__biz=Mzg3NTA5MjkyNQ==&mid=2247608158&idx=1&sn=ddc1a3c4dc8dbca67ed8476b2f43ef4f',
#   'title': '隔离区误放阳性病人，发布会临时取消，停更全国确诊数！美国疾控中心这波操作惹众怒',
#   'title_eng': "The release of positive patients in the quarantine area was temporarily cancelled, and the number of confirmed diagnoses nationwide was stopped! U.S. Centers for Disease Control's operation angers everyone",
#   'nickname': '每日经济新闻',
#   'created_at': '2020-03-05',
#   'archive': 'gh_2424e6d48203_2020-03-05_2247608158_8d6VR5zAmu.y.tar.gz',
#   'censored_date': '2020-03-06 16:50:17',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 17:11:01'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5OTIxMTExMg==&mid=2652923424&idx=2&sn=1528dddb0eae79688c6a0ceb3bf2fe23',
#   'title': '紧急预警！青岛已有多人中招！',
#   'title_eng': 'Emergency warning! Many people have been recruited in Qingdao!',
#   'nickname': '大众网青岛',
#   'created_at': '2020-03-06',
#   'archive': 'gh_b0f015892c4a_2020-03-06_2652923424_q3oj8fnQ0X.y.tar.gz',
#   'censored_date': '2020-03-06 17:54:27',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 18:51:52'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzAxMjk0ODM0Ng==&mid=2247485904&idx=1&sn=6508b2ec31c02c4653a31374e2aecdc1',
#   'title': '程抄抄，人不可以无耻到脱裤子玩鸟的地步',
#   'title_eng': 'Cheng Chaoshao, one cannot shamelessly take off his pants and play with birds',
#   'nickname': '苍山夜谈',
#   'created_at': '2020-03-06',
#   'archive': 'gh_d487d6714a24_2020-03-06_2247485904_jpOKyowukB.y.tar.gz',
#   'censored_date': '2020-03-07 19:34:08',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-08 05:13:31'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4OTQ2MTUwNw==&mid=2651226732&idx=3&sn=74214262b5b0b023079d11118d44f57b',
#   'title': '致敬！禅城最美逆行者！',
#   'title_eng': 'pay tribute! The most beautiful retrograde in Chancheng!',
#   'nickname': '禅城发布',
#   'created_at': '2020-03-04',
#   'archive': 'gh_c5ab01d46c6d_2020-03-04_2651226732_KpXwMGHB0u.y.tar.gz',
#   'censored_date': '2020-03-04 18:54:08',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 19:52:24'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU5NjU0NDU1OA==&mid=2247521850&idx=2&sn=814382118a64d987553581a8fd358347',
#   'title': '学者丨戴建业：面对方方，我们这些爷们难道就没一点愧意？',
#   'title_eng': "Scholar 丨 Jianye Dai: Facing Fang Fang, aren't we gentlemen ashamed?",
#   'nickname': '新三届',
#   'created_at': '2020-03-04',
#   'archive': 'gh_4c1810cb0fcf_2020-03-04_2247521850_LagXKBCAE7.y.tar.gz',
#   'censored_date': '2020-03-05 20:47:04',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-06 20:49:08'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MTI4MjUxMw==&mid=2653666537&idx=2&sn=e29d43d4847c497b98d93d2adfef310a',
#   'title': '招聘｜36氪Tech星球、雷达财经、中国改革报/改革网湾区智库、西藏阿古顿巴、海南日报',
#   'title_eng': 'Recruitment ｜ 36 氪 Tech Planet, Radar Finance, China Reform News / Reform Network Bay Area Think Tank, Tibet Agudamba, Hainan Daily',
#   'nickname': 'AI蓝媒汇',
#   'created_at': '2020-03-04',
#   'archive': 'gh_58828820c375_2020-03-04_2653666537_VuOAKxiR9p.y.tar.gz',
#   'censored_date': '2020-03-05 22:56:32',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 22:24:05'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0MTY5NzY0Mg==&mid=2247491286&idx=3&sn=ae8243830d425a466e2ecbeaa3369fa8',
#   'title': '专家：给非洲留学生每人每年也就10万元左右，真的不算多！',
#   'title_eng': 'Expert: For African international students, each person is about 100,000 yuan per year, really not much!',
#   'nickname': '遮眼看天',
#   'created_at': '2020-03-04',
#   'archive': 'gh_b984621ff266_2020-03-04_2247491286_kz5ctHNlZ0.y.tar.gz',
#   'censored_date': '2020-03-06 00:18:26',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 23:14:11'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIxMjMyMTQyMg==&mid=2247529399&idx=1&sn=868b31113446c40cc20aaa874c26d1fe',
#   'title': '西海岸书记孙永红卸任胶州职务！新区如何打赢“增速”翻身仗？',
#   'title_eng': 'West Coast Secretary Sun Yonghong stepped down from Jiaozhou! How does the new district win the growth battle?',
#   'nickname': '凤凰网青岛',
#   'created_at': '2020-03-04',
#   'archive': 'gh_20542841a698_2020-03-04_2247529399_uhjxkSK2nE.y.tar.gz',
#   'censored_date': '2020-03-04 23:43:49',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 23:16:31'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MzQ5MDUyNQ==&mid=2652449458&idx=1&sn=2af6be75393dab866cf7b41cb1565ef0',
#   'title': '曝光！长兴这4家餐饮店餐具检测不合格！有你常去的吗？以后谁还敢去！',
#   'title_eng': "exposure! Changxing's 4 restaurants have failed the tableware test! Do you go often? Who dares to go in the future!",
#   'nickname': '长兴人',
#   'created_at': '2020-03-06',
#   'archive': 'gh_eb9386049200_2020-03-06_2652449458_ikFS9uAWgs.y.tar.gz',
#   'censored_date': '2020-03-06 22:32:02',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-08 09:09:38'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI1NDY5NDM3OQ==&mid=2247530089&idx=1&sn=879f792940f4e39bb9a8d833a055d3e3',
#   'title': '“我不种族歧视，但我反对外国人定居中国”',
#   'title_eng': 'I do not discriminate, but I am opposed to foreigners settling in China',
#   'nickname': '凤凰WEEKLY',
#   'created_at': '2020-03-06',
#   'archive': 'gh_44e51cde40c7_2020-03-06_2247530089_zoubODP3Qi.y.tar.gz',
#   'censored_date': '2020-03-06 23:27:05',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-08 09:16:12'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIzMTY2NTc0OQ==&mid=2247485762&idx=2&sn=d6317c22bde0c32d7398e6d3ad82f3b0',
#   'title': '“我想逃出武汉！”',
#   'title_eng': 'I want to escape Wuhan!',
#   'nickname': '秘闻爆光',
#   'created_at': '2020-03-04',
#   'archive': 'gh_94d9b14108ec_2020-03-04_2247485762_0ox2Inm5pu.y.tar.gz',
#   'censored_date': '2020-03-07 01:57:26',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-05 22:29:52'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953616&idx=1&sn=11c013cf5511a33968c25658d4ca9bb6',
#   'title': '今日灵修：受苦的心志是我们的兵器,不是标竿(含音频)',
#   'title_eng': 'Devotion today: suffering is our weapon, not a benchmark (including audio)',
#   'nickname': '生命季刊',
#   'created_at': '2020-03-05',
#   'archive': 'gh_785a6e62ca80_2020-03-05_2688953616_4vAqjxep3w.y.tar.gz',
#   'censored_date': '2020-03-07 02:30:11',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 11:32:55'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzUyNjYyNTQzOA==&mid=2247513861&idx=3&sn=27e8e8204eedda46230e7d668571e491',
#   'title': '圣经预言（ 一看吓一跳）',
#   'title_eng': 'Bible Prophecy',
#   'nickname': '牧者讲道',
#   'created_at': '2020-03-06',
#   'archive': 'gh_ab6c4e04286d_2020-03-06_2247513861_yLPrs7ob0q.y.tar.gz',
#   'censored_date': '2020-03-08 11:12:16',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 10:23:10'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzUyNjYyNTQzOA==&mid=2247513861&idx=1&sn=2713c24b6ef8dd8c2017ec3ed4b856a8',
#   'title': '心态好的人，蒙福一辈子（写得真好！）',
#   'title_eng': 'A good-minded person, blessed for a lifetime (good writing!)',
#   'nickname': '牧者讲道',
#   'created_at': '2020-03-06',
#   'archive': 'gh_ab6c4e04286d_2020-03-06_2247513861_KSpY3oZJhu.y.tar.gz',
#   'censored_date': '2020-03-08 11:13:02',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 10:23:56'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIxNzgzMDQzMA==&mid=2247492791&idx=1&sn=575b994e2b666924b6d151e892ca8dfd',
#   'title': '痛心！河南一贫困户女儿因无法在家上网课 吞药自杀',
#   'title_eng': 'Distressed! Daughter of a poor household in Henan commits suicide due to inability to take online classes at home',
#   'nickname': '春草微视',
#   'created_at': '2020-03-02',
#   'archive': 'gh_85ceeb96c96a_2020-03-02_2247492791_PbUL4aWvhw.y.tar.gz',
#   'censored_date': '2020-03-06 20:37:32',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-07 08:11:56'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU2MzEyMjEyMQ==&mid=2247515314&idx=3&sn=0d331a1071536e47895d1eb473c2e91f',
#   'title': '何大一：我不怀疑病毒源于中国  美国不大可能失控',
#   'title_eng': 'Dr. He: I do n’t suspect that the virus originated in China.',
#   'nickname': '纽约华人资讯网',
#   'created_at': '2020-03-07',
#   'archive': 'gh_fe0e2ce6a0b5_2020-03-07_2247515314_QYRWkyUPej.y.tar.gz',
#   'censored_date': '2020-03-07 08:53:29',
#   'censored_msg': '该内容已被发布者删除'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI2NjM1Mzc0NQ==&mid=2247494754&idx=1&sn=03abbaeb52270d532c2fa096854e5193',
#   'title': '注意！喝这几种酒可能等于在喝毒药，常喝酒的抓紧看看你喝过没。',
#   'title_eng': 'note! Drinking these kinds of alcohol may be equivalent to drinking poison. Hold on to drinking and see if you have ever drunk.',
#   'nickname': '中式说法',
#   'created_at': '2020-03-06',
#   'archive': 'gh_228a9dbecdc5_2020-03-06_2247494754_B6ztjbP7mk.y.tar.gz',
#   'censored_date': '2020-03-07 11:38:11',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-06 11:22:26'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI2NjM1Mzc0NQ==&mid=2247494754&idx=2&sn=f17a53d4764cbedd9ba19039e5b87412',
#   'title': '假的，全都是假的！武汉上空的喊声惊动了中央领导',
#   'title_eng': 'Fake, all are fake! The shouts over Wuhan alarmed the central leadership',
#   'nickname': '中式说法',
#   'created_at': '2020-03-06',
#   'archive': 'gh_228a9dbecdc5_2020-03-06_2247494754_uUkry2YHxE.y.tar.gz',
#   'censored_date': '2020-03-07 12:27:46',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-06 10:18:32'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU1ODM1ODM1Ng==&mid=2247490162&idx=1&sn=0529dafc9cc4d62aeb72fda36d0dad6f',
#   'title': '注意！喝这几种酒可能等于在喝毒药，常喝酒的抓紧看看你喝过没。',
#   'title_eng': 'note! Drinking these kinds of alcohol may be equivalent to drinking poison. Hold on to drinking and see if you have ever drunk.',
#   'nickname': '虎次郎',
#   'created_at': '2020-03-06',
#   'archive': 'gh_610312e22ed3_2020-03-06_2247490162_V9SYOKbLDX.y.tar.gz',
#   'censored_date': '2020-03-07 11:52:07',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-06 10:58:50'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4MDI3OTkxMA==&mid=2651554017&idx=1&sn=4d4392d0b1140856176ba56b0200240f',
#   'title': '女人“糟蹋”脸蛋的三个恐怖行为，敷面膜竟然排第一，还有......',
#   'title_eng': "The three horrible acts of a woman's bad face are actually ranked first with a mask, and ...",
#   'nickname': '她言他语',
#   'created_at': '2020-03-06',
#   'archive': 'gh_ec6dcd28a470_2020-03-06_2651554017_DJ4k9Nyzn7.y.tar.gz',
#   'censored_date': '2020-03-07 11:53:18',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-06 10:27:53'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIzNjc1NzUzMw==&mid=2247538454&idx=4&sn=2fdfd8f51a7f2f930a1f627cd5278ccf',
#   'title': '加州最新无人驾驶出租车报告：PonyAI运营总里程超Waymo，单车效率也更高',
#   'title_eng': "California's latest driverless taxi report: PonyAI's total mileage exceeds Waymo, and bicycles are more efficient",
#   'nickname': '量子位',
#   'created_at': '2020-03-07',
#   'archive': 'gh_114e76fd6e5d_2020-03-07_2247538454_igHkNR3b0l.y.tar.gz',
#   'censored_date': '2020-03-07 14:34:26',
#   'censored_msg': '该内容已被发布者删除'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5ODAzMjQxMg==&mid=2650365367&idx=2&sn=898a4b50d8b27eb3b8cca4c4d5d5291d',
#   'title': '记者暗访：疫期江西这两地窗口服务令人担心……',
#   'title_eng': 'An unannounced visit by reporters: The window services in Jiangxi in the epidemic period are worrying ...',
#   'nickname': '江南都市报',
#   'created_at': '2020-03-05',
#   'archive': 'gh_b62058001651_2020-03-05_2650365367_3q50SZc7ph.y.tar.gz',
#   'censored_date': '2020-03-06 12:20:59',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 13:18:08'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953637&idx=2&sn=e4fd094d4c9a9f62fb0231f4ace93d35',
#   'title': '王明道:嫉恨/说谎…已成了何等普通的罪!(含音频)',
#   'title_eng': 'Wang Mingdao: Jealousy / lying ... what an ordinary sin has become! (With audio)',
#   'nickname': '生命季刊',
#   'created_at': '2020-03-06',
#   'archive': 'gh_785a6e62ca80_2020-03-06_2688953637_JvxMuIbk6z.y.tar.gz',
#   'censored_date': '2020-03-07 13:59:05',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 16:31:37'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzY4OTEyNA==&mid=2688953637&idx=1&sn=90d4187cfb8291d29d83dc78f8246312',
#   'title': '今日灵修：\u200b脚前灯，只照亮行走的人(含音频)',
#   'title_eng': 'Today ’s spiritual practice: Foot lamp, only to light people who walk (including audio)',
#   'nickname': '生命季刊',
#   'created_at': '2020-03-06',
#   'archive': 'gh_785a6e62ca80_2020-03-06_2688953637_sqaDeEKQ1F.y.tar.gz',
#   'censored_date': '2020-03-07 13:59:28',
#   'censored_msg': '此帐号已被屏蔽,',
#   'update_date': '2020-03-06 16:32:00'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5MzAyMzA1NQ==&mid=2650696915&idx=2&sn=aecc966d5a6a4fee74c70af58ef9179e',
#   'title': '印尼拟允许将镍冶炼厂废物处置到深海',
#   'title_eng': 'Indonesia intends to allow nickel smelter waste to be disposed of in the deep sea',
#   'nickname': '中国镍业网',
#   'created_at': '2020-03-06',
#   'archive': 'gh_179ee720307e_2020-03-06_2650696915_JC1XFOdUzL.y.tar.gz',
#   'censored_date': '2020-03-07 14:24:20',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 17:40:33'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI1ODI4MjY5Mg==&mid=2247490847&idx=1&sn=04837f7a37a6856312a6d6ba0afb6069',
#   'title': '上海教授：孙杨不是国家的骄傲是国家的耻辱！孙杨母亲：奋斗被强权谎言扼杀',
#   'title_eng': 'Professor Shanghai: Sun Yang is not the pride of the country but the shame of the country! Mother Sun Yang: Struggle Strangled by Lies of Power',
#   'nickname': '自由新青年V',
#   'created_at': '2020-03-04',
#   'archive': 'gh_74e34350ad6b_2020-03-04_2247490847_lLanOudrhR.y.tar.gz',
#   'censored_date': '2020-03-06 15:04:50',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-07 15:14:04'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI3MTQzNjYxNw==&mid=2247517733&idx=6&sn=a08b41804e9d97651197436526c60b9f',
#   'title': '武大首发新冠性别差异研究：女性潜伏期更长',
#   'title_eng': "Study on Gender Differences of Wuhan University's First New Crown: Women's Incubation Period Is Longer",
#   'nickname': '红星新闻',
#   'created_at': '2020-03-06',
#   'archive': 'gh_1ede6c42db01_2020-03-06_2247517733_9KEPbfoT0F.y.tar.gz',
#   'censored_date': '2020-03-07 14:47:31',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 17:08:04'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MTk1MjIwODAwMQ==&mid=2650845867&idx=3&sn=9fffeda03fd0dcd23a36497f022469f0',
#   'title': '李文亮、柳帆、夏思思等34名殉职医护被追授全国防疫先进个人称号',
#   'title_eng': 'Li Wenliang, Liu Fan, Xia Sisi and 34 other unscrupulous doctors and nurses were awarded the title of National Advanced Individual for Epidemic Prevention',
#   'nickname': '南方都市报',
#   'created_at': '2020-03-05',
#   'archive': 'wxid_4783107810411_2020-03-05_2650845867_JtfxeH3TVY.y.tar.gz',
#   'censored_date': '2020-03-06 17:17:59',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 17:11:24'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU4MjUzNDc2Nw==&mid=2247490616&idx=4&sn=a121c0e7b2ca53e40c69dab949382845',
#   'title': '“我想逃出武汉！”',
#   'title_eng': 'I want to escape Wuhan!',
#   'nickname': '历史微时刻',
#   'created_at': '2020-03-05',
#   'archive': 'gh_31930173e92d_2020-03-05_2247490616_xE1WCQ203g.y.tar.gz',
#   'censored_date': '2020-03-06 18:36:21',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-07 19:49:34'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA5NjA1ODY4NQ==&mid=2650999511&idx=4&sn=70824ba640d112e23d63377cc24d2d49',
#   'title': '“我想逃出武汉！”',
#   'title_eng': 'I want to escape Wuhan!',
#   'nickname': '百年树人',
#   'created_at': '2020-03-06',
#   'archive': 'gh_759087605909_2020-03-06_2650999511_tVOxIirokY.y.tar.gz',
#   'censored_date': '2020-03-07 19:49:11',
#   'censored_msg': '此内容因违规无法查看'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NTE0ODc2Nw==&mid=2650464938&idx=4&sn=0a942a163ba414a9c933ee98457827bf',
#   'title': '全球近3亿学生停课抗疫，联合国警告教育不平等加剧',
#   'title_eng': 'Nearly 300 million students worldwide have suspended classes to fight the epidemic, and the United Nations warns of rising education inequality',
#   'nickname': '界面新闻',
#   'created_at': '2020-03-05',
#   'archive': 'gh_93119cc8064a_2020-03-05_2650464938_iE8U6ZOpex.y.tar.gz',
#   'censored_date': '2020-03-05 20:42:22',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 21:07:34'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA3NjM5MjIwOQ==&mid=2651800526&idx=1&sn=8724462ac8bf3db69c7a1aad3fa114d5',
#   'title': '天上掉馅饼？赎回10万基金到账20万，这样的BUG我也想要！&quot;幸运乌龙&quot;时隔4年再现，到底所为何因？',
#   'title_eng': 'A pie in the sky? Redemption of 100,000 funds to 200,000 accounts, I also want such a bug!',
#   'nickname': '券商中国',
#   'created_at': '2020-03-07',
#   'archive': 'gh_6df2146bcb82_2020-03-07_2651800526_cM0s6OAV8L.y.tar.gz',
#   'censored_date': '2020-03-07 21:42:59',
#   'censored_msg': '该内容已被发布者删除'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzAwMzU0MA==&mid=2247505402&idx=5&sn=f57a58ed65cf701b21958f7295395d06',
#   'title': '天际线资产三年不增值，平安买楼图什么？',
#   'title_eng': 'Skyline assets have not increased in value for three years.',
#   'nickname': '华尔街见闻',
#   'created_at': '2020-03-03',
#   'archive': 'gh_64b9211187ab_2020-03-03_2247505402_tcKsaBdQf2.y.tar.gz',
#   'censored_date': '2020-03-05 19:49:04',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 22:12:03'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzIwMTkxMDUxNA==&mid=2247497282&idx=1&sn=3484f9efc777c341fd6294b6c2cafd8f',
#   'title': '求职就业！洛阳发布重要通知......',
#   'title_eng': 'Job hunting! Luoyang issues important notice ...',
#   'nickname': '洛阳人事',
#   'created_at': '2020-03-07',
#   'archive': 'gh_afad949b93dd_2020-03-07_2247497282_NoE4Tf7ilw.y.tar.gz',
#   'censored_date': '2020-03-07 22:37:52',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 20:21:17'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0MTY5NzY0Mg==&mid=2247491294&idx=2&sn=a3e8d5a0bc10a945b712830664b0c2f2',
#   'title': '“我想逃出武汉！”',
#   'title_eng': 'I want to escape Wuhan!',
#   'nickname': '遮眼看天',
#   'created_at': '2020-03-05',
#   'archive': 'gh_b984621ff266_2020-03-05_2247491294_7tI4U1lOPi.y.tar.gz',
#   'censored_date': '2020-03-06 22:16:01',
#   'censored_msg': '此内容因违规无法查看',
#   'update_date': '2020-03-07 23:10:27'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0MTY5NzY0Mg==&mid=2247491306&idx=4&sn=0b6d7938f29290320e95814a13a118b2',
#   'title': '梁宏达：历史重大转折关头病毒病菌起非常大的作用',
#   'title_eng': 'Liang Hongda: A major turning point in the history of viruses',
#   'nickname': '遮眼看天',
#   'created_at': '2020-03-06',
#   'archive': 'gh_b984621ff266_2020-03-06_2247491306_V9CuBi03Od.y.tar.gz',
#   'censored_date': '2020-03-07 23:52:04',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 02:15:48'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA4MTkzMTYwMw==&mid=2751376728&idx=5&sn=64daf2e350011faa75ca28e8cda67828',
#   'title': '口臭七八年，鼻子出气都是臭的！用它漱口，30秒消除口臭，30天黄牙变白',
#   'title_eng': 'Bad breath for seven or eight years, the nose is out of breath! Use it to gargle, remove bad breath in 30 seconds, and turn yellow teeth into white in 30 days',
#   'nickname': '葫芦岛都市网',
#   'created_at': '2020-03-06',
#   'archive': 'gh_8dd3af29215d_2020-03-06_2751376728_vg284eU0xr.y.tar.gz',
#   'censored_date': '2020-03-07 23:50:10',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-06 23:33:38'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MjM5NzE1ODI3OQ==&mid=2653197644&idx=4&sn=77f6e10941e6d723253cd8f195d5a673',
#   'title': '内蒙古出台《关于阶段性减免企业社会保险费的通知》',
#   'title_eng': 'Inner Mongolia issued Notice on periodic reduction and exemption of corporate social insurance premiums',
#   'nickname': '内蒙古日报',
#   'created_at': '2020-03-06',
#   'archive': 'gh_b7047f0cbe74_2020-03-06_2653197644_fuizWoe9vQ.y.tar.gz',
#   'censored_date': '2020-03-06 23:51:49',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-08 01:05:36'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0NTYxNTk0Mg==&mid=2247492248&idx=2&sn=373bd0a9bf8f64dc41d55488ca7962ba',
#   'title': '爸爸妈妈，我要和你们在一起',
#   'title_eng': 'Mom and Dad, I want to be with you',
#   'nickname': '高碎说一不二',
#   'created_at': '2020-03-08',
#   'archive': 'gh_ae5bc138b1e1_2020-03-08_2247492248_ngGCyaeF3j.y.tar.gz',
#   'censored_date': '2020-03-08 01:06:05',
#   'censored_msg': '此内容因违规无法查看'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzU0MTY5NzY0Mg==&mid=2247491306&idx=1&sn=04388d2bd00d29c06903015c33105e7e',
#   'title': '任大炮发声：非洲留学生带来大量艾滋',
#   'title_eng': 'Ren Cannon speaks: African students bring a lot of AIDS',
#   'nickname': '遮眼看天',
#   'created_at': '2020-03-06',
#   'archive': 'gh_b984621ff266_2020-03-06_2247491306_0lICgqdtLo.y.tar.gz',
#   'censored_date': '2020-03-07 23:51:18',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-08 09:05:43'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzUyNjYyNTQzOA==&mid=2247513861&idx=2&sn=3ba37d7a60aa579ce7f3994fc90f2a34',
#   'title': '看完终于明白如何祷告了，后悔知道的太晚！',
#   'title_eng': 'After reading it, I finally understood how to pray. I regret knowing it too late!',
#   'nickname': '牧者讲道',
#   'created_at': '2020-03-06',
#   'archive': 'gh_ab6c4e04286d_2020-03-06_2247513861_1pOIGWuSCk.y.tar.gz',
#   'censored_date': '2020-03-08 11:12:39',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 10:23:33'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzI3NzQ0OTQ5Mw==&mid=2247493323&idx=1&sn=1a39bc93b178af9b670a0784726e3736',
#   'title': '武汉医生病愈者:事实就在那,他们为何要撒谎？',
#   'title_eng': 'Doctor Wuhan Healed: The fact is there, why should they lie?',
#   'nickname': '新退休生活',
#   'created_at': '2020-03-06',
#   'archive': 'gh_7134776aea5c_2020-03-06_2247493323_S2TyOWlich.y.tar.gz',
#   'censored_date': '2020-03-07 10:43:16',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-08 11:52:51'},
#  {'url': 'mp.weixin.qq.com/s?__biz=MzA3Nzk3NzYxOQ==&mid=2650958121&idx=2&sn=75855ec2a22d81cf25c39e166ac59d1c',
#   'title': '美团抽成22%！引发餐饮业公愤！看他的成长之路',
#   'title_eng': 'The US group draws 22%! Caused public outrage in the catering industry! See his growth',
#   'nickname': '齐俊杰看财经',
#   'created_at': '2020-03-07',
#   'archive': 'gh_7c1e674cacab_2020-03-07_2650958121_Wnm1c7LUM2.y.tar.gz',
#   'censored_date': '2020-03-08 12:04:30',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 10:52:06'},
#  {'url': 'mp.weixin.qq.com/s?__biz=Mzg2NzA1NzcyMA==&mid=2247501756&idx=3&sn=abb0d832052d9ee5b957c2d34920083d',
#   'title': '用它抹脸，7天白1度，色斑，暗沉通通消失，15天黄脸婆变少女 !',
#   'title_eng': 'Use it to wipe your face, 7 days white, 1 degree, stains, dullness disappear, 15 days yellow face woman becomes a girl!',
#   'nickname': '言情说',
#   'created_at': '2020-03-06',
#   'archive': 'gh_00e66b7f0a40_2020-03-06_2247501756_r7Z3DGv06s.y.tar.gz',
#   'censored_date': '2020-03-08 11:35:04',
#   'censored_msg': '该内容已被发布者删除',
#   'update_date': '2020-03-07 10:38:39'}]

# %% [markdown]
# The latest censored article was the last one.

# %%
data[-1]
# Out:
# {'url': 'mp.weixin.qq.com/s?__biz=Mzg2NzA1NzcyMA==&mid=2247501756&idx=3&sn=abb0d832052d9ee5b957c2d34920083d',
#  'title': '用它抹脸，7天白1度，色斑，暗沉通通消失，15天黄脸婆变少女 !',
#  'title_eng': 'Use it to wipe your face, 7 days white, 1 degree, stains, dullness disappear, 15 days yellow face woman becomes a girl!',
#  'nickname': '言情说',
#  'created_at': '2020-03-06',
#  'archive': 'gh_00e66b7f0a40_2020-03-06_2247501756_r7Z3DGv06s.y.tar.gz',
#  'censored_date': '2020-03-08 11:35:04',
#  'censored_msg': '该内容已被发布者删除',
#  'update_date': '2020-03-07 10:38:39'}

# %%
# insert your own keys and secrets here...
CONSUMER_KEY = ""
CONSUMER_SECRET = ""
ACCESS_TOKEN = ""
ACCESS_TOKEN_SECRET = ""

# before we can make Twitter API calls, we need to initialize a few things...
from tweepy import OAuthHandler, API

# setup the authentication
auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# create an object we will use to communicate with the Twitter API
api = API(auth)

# %% [markdown]
# Tweet the latest article

# %%
from time import sleep
from requests import get


url = 'https://wechatscope.jmsc.hku.hk/api/update_weixin_public?days=7'

# keep track of the previous wired link/url that we tweeted
prev_tweeted_link = ''

# loop forever!
while True:
    
     # fetch and parse the url
    response = get(url)
    data=response.json()

    # get the latest article 
    latest_article = data[-1]

    # take the link of the first story and see if we've tweeted it before
    link = latest_article['url']
    if link != prev_tweeted_link:
            
        print('new article - lets tweet it: ' + link)
        
        # build the text of our tweet
        tweet_text =latest_article['title'] + '   ' +  "censored date:"+ " " + latest_article['censored_date'] + '   ' + "censored message:" + " " + latest_article["censored_msg"] + " " + "https://wechatscope.jmsc.hku.hk/api/html?fn="+latest_article['archive']
        
        # fire it off to twitter
        api.update_status(status=tweet_text)
        
        # keep track of the this link that we just tweeted
        prev_tweeted_link = link
    else:
        print('no new article...lets wait a little while')

    # sleep for a little while
    sleep(300)

    
# if you want to stop this script, hit the Stop button in your notebook
# Out:
# new article - lets tweet it: mp.weixin.qq.com/s?__biz=MjM5NTk0Nzg0MQ==&mid=2665720512&idx=1&sn=5291a6a5db7fd7f42c4f4b46ba049c26
# new article - lets tweet it: mp.weixin.qq.com/s?__biz=MzUyMDYwMTA5Ng==&mid=2247485604&idx=4&sn=5a56f91b268dc14e01a771fc8023e173
# new article - lets tweet it: mp.weixin.qq.com/s?__biz=MzI4ODA4MDczMw==&mid=2247487572&idx=1&sn=64306f73ccc267c1e12adf60e53569b4
# no new article...lets wait a little while
# no new article...lets wait a little while
# no new article...lets wait a little while
# no new article...lets wait a little while
# no new article...lets wait a little while
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-9afb40332e6e> in <module>
#      12
#      13      # fetch and parse the url
# ---> 14     response = get(url)
#      15     data=response.json()
#      16
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     345             or IS_SECURETRANSPORT):
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#     349         warnings.warn(
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     454         while True:
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#     458                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# /opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1912         :return: None.
#    1913         """
# -> 1914         result = _lib.SSL_do_handshake(self._ssl)
#    1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# KeyboardInterrupt:

# %% [markdown]
# **Some variations:**
#
# Tweet out the articles that were manually deleted by the censors: taking out those articles that are "deleted by the author" (which usually means that they were identified and deleted by the algorithm).

# %%
from time import sleep
from requests import get
import json

url = 'https://wechatscope.jmsc.hku.hk/api/update_weixin_public?days=7'

# keep track of the previous wired link/url that we tweeted
prev_tweeted_link = ''

# loop forever!
while True:
    
     # fetch and parse the url
    response = get(url)
    data=response.json()

    # get the latest article 
    latest_article = data[-1]

    # take the link of the first story and see if we've tweeted it before
    link = latest_article['url']
    if link != prev_tweeted_link:
        if latest_article['censored_msg']!="该内容已被发布者删除":
            
            print('new article - lets tweet it: ' + link)
        
        # build the text of our tweet
            tweet_text =latest_article['title'] + ' ' + latest_article['title_eng'] + ' ' +  "censored date:"+ " " + latest_article['censored_date'] + ' ' + "censored message:" + " " + latest_article["censored_msg"] + " " +"https://wechatscope.jmsc.hku.hk/api/html?fn="+latest_article['archive']
        
        # fire it off to twitter
            api.update_status(status=tweet_text)
        
        # keep track of the this link that we just tweeted
            prev_tweeted_link = link
        else:
            print('the article was deleted by the author...lets wait a little while')
    else:
        print('no new article...lets wait a little while')

    # sleep for a little while
    sleep(60)

    
# if you want to stop this script, hit the Stop button in your notebook
# Out:
# new article - lets tweet it: mp.weixin.qq.com/s?__biz=MzUyMDYwMTA5Ng==&mid=2247485616&idx=3&sn=d0e53d8914acab894b194f89f0ae8f88
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-bfaf0f557fd9> in <module>
#      39
#      40     # sleep for a little while
# ---> 41     sleep(60)
#      42
#      43
#
# KeyboardInterrupt:

# %% [markdown]
# Tweet out all the available articles that were not deleted by the author.

# %%
from time import sleep
from requests import get

url = 'https://wechatscope.jmsc.hku.hk/api/update_weixin_public?days=7'

response = get(url)
data=response.json()

for article in data:
    if article['censored_msg']!="该内容已被发布者删除":
        tweet_text =article['title'] + '   ' +  "censored date:"+ " " + article['censored_date'] + '   ' + "censored message:" + " " + article["censored_msg"] + " " + "https://wechatscope.jmsc.hku.hk/api/html?fn="+article['archive']
        api.update_status(status=tweet_text)
    else:
        print("deleted")
# Out:
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-10-bdca64907128> in <module>
#      10     if article['censored_msg']!="该内容已被发布者删除":
#      11         tweet_text =article['title'] + '   ' +  "censored date:"+ " " + article['censored_date'] + '   ' + "censored message:" + " " + article["censored_msg"] + " " + "https://wechatscope.jmsc.hku.hk/api/html?fn="+article['archive']
# ---> 12         api.update_status(status=tweet_text)
#      13     else:
#      14         print("deleted")
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/api.py in update_status(self, *args, **kwargs)
#     191             allowed_param=['status', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'auto_populate_reply_metadata', 'lat', 'long', 'source', 'place_id', 'display_coordinates'],
#     192             require_auth=True
# --> 193         )(post_data=post_data, *args, **kwargs)
#     194
#     195     def media_upload(self, filename, *args, **kwargs):
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
#     235             # Parse the response payload
#
# TweepError: [{'code': 187, 'message': 'Status is a duplicate.'}]
